# %% [markdown]
# # Homework 1
# ### Gavin Martin
# ### CS 344
#
#
# #### Question 1:
#
# While I think there may be some value to introspection, I don't believe that value can be found using the same methodologies that Wundt used. It can be helpful to know and understand how the brain stores information however measuring feelings and sensations would be mostly pointless when it comes to modeling the Human Brain, since with AI, anything we build won't actually be alive, it will simply act as if it is.
#     I do think it might be a wise decision to look at how the human brain reaches for information, analyzes situations, and processes memory. To some degree neural nets in AI are comparable to our own web of neurons. When we think of something, we can often trigger old memories which are stored in our brain like some sort of tree. When we look at an animal, we know what animal it is, because we have seen it before. Our brain traverses through the web of memories to understand what it has learned about that animal in past memories. Machine Learning must do the same with the information it has learned. This is where introspection may be valuable. Analyzing feelings, sensations, and emotions would likely be less valueable unless you believe that you can create a living thinking being with your simulation.

# %%
from search import Problem, hill_climbing, UndirectedGraph, simulated_annealing, exp_schedule

import random
import time
import math

from search import Problem, hill_climbing, UndirectedGraph, simulated_annealing, exp_schedule

import random
import time
import math


class TSP(Problem):

    def __init__(self, locations, initial):
        self.initial = initial
        self.locations = locations
        self.unVisitedLocations = list(locations.keys())
        self.currentState = initial
        self.cost = 0

    # Add Every univisted city to the list of potential actions 
    def actions(self, state):
        actions = []
        for location in self.locations:
            if location in self.unVisitedLocations and location != state:
                actions.append(location)
        return actions

    # Calculate distance function (used later in value)
    def calculate_distance(self, location1, location2):
        x1 = location1[0]
        x2 = location2[0]
        y1 = location1[1]
        y2 = location2[1]
        dist = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        return dist

    # gets the result of moving to that state and puts it into cost
    def result(self, state, action):
        new_state = action
        self.currentState = new_state
        oldLocation = self.locations.get(state)
        newLocation = self.locations.get(new_state)
        tripCost = self.calculate_distance(oldLocation, newLocation)
        self.cost = self.cost - tripCost
        self.unVisitedLocations.remove(new_state)
        print("Travel to " + action + " with a travel cost of " + str(tripCost))
        return new_state

    # tests to see if it has arrived at all states 
    def goal_test(self, state):
        if len(self.unVisitedLocations) == 0:
            return True
        else:
            return False

    # Gets the value of the state givn its travel cost
    def value(self, state):
        oldLocation = self.locations.get(self.currentState)
        newLocation = self.locations.get(state)
        value = self.cost - self.calculate_distance(oldLocation, newLocation)
        return value



if __name__ == '__main__':
    romania = UndirectedGraph(dict(
        arad=dict(zerind=75, sibiu=140, timisoara=118),
        bucharest=dict(urziceni=85, pitesti=101, giurgiu=90, fagaras=211),
        craiova=dict(dobreta=120, rimnicuvilcea=146, pitesti=138),
        dobreta=dict(mehadia=75),
        eforie=dict(hirsova=86),
        fagaras=dict(sibiu=99),
        hirsova=dict(urziceni=98),
        iasi=dict(vaslui=92, neamt=87),
        lugoj=dict(timisoara=111, mehadia=70),
        oradea=dict(zerind=71, sibiu=151),
        pitesti=dict(rimnicuvilcea=97),
        rimnicuvilcea=dict(sibiu=80),
        urziceni=dict(vaslui=142)))

    locations = dict(
        arad=(91, 492),
        bucharest=(400, 327),
        craiova=(253, 288),
        dobreta=(165, 299),
        eforie=(562, 293),
        fagaras=(305, 449),
        giurgiu=(375, 270),
        hirsova=(534, 350),
        iasi=(473, 506),
        lugoj=(165, 379),
        mehadia=(168, 339),
        neamt=(406, 537),
        oradea=(131, 571),
        pitesti=(320, 368),
        rimnicuvilcea=(233, 410),
        sibiu=(207, 457),
        timisoara=(94, 410),
        urziceni=(456, 350),
        vaslui=(509, 444),
        zerind=(108, 531))

initial1 = random.choice(list(locations.keys()))
problem1 = TSP(locations, initial1)
initial2 = random.choice(list(locations.keys()))
problem2 = TSP(locations, initial2)


hill_solution = hill_climbing(problem1)
print('\nHill-climbing solution       x: ' + '\tvalue: ' + str(math.fabs(problem1.value(hill_solution))) + "\n\n")


annealing_solution = simulated_annealing(problem2, exp_schedule(k=20, lam=0.005, limit=15000))
print('\nAnnealing solution       x: ' + '\tvalue: ' + str(math.fabs(problem2.value(annealing_solution))) + "\n\n")
# Out:
# Travel to arad with a travel cost of 465.20210661603846
# Travel to bucharest with a travel cost of 135.95955280891445
# Travel to craiova with a travel cost of 287.75857936819193
# Travel to dobreta with a travel cost of 372.5077180408481
# Travel to eforie with a travel cost of 63.50590523722971
# Travel to fagaras with a travel cost of 249.48346638605133
# Travel to giurgiu with a travel cost of 177.99157283422156
# Travel to iasi with a travel cost of 167.5022387910084
# Travel to lugoj with a travel cost of 370.1378121727095
# Travel to mehadia with a travel cost of 366.16526323505894
# Travel to neamt with a travel cost of 226.61200321253946
# Travel to oradea with a travel cost of 459.6194077712559
# Travel to pitesti with a travel cost of 214.75567512873786
# Travel to rimnicuvilcea with a travel cost of 306.9218141481638
# Travel to sibiu with a travel cost of 344.06104109590785
# Travel to timisoara with a travel cost of 444.07206622349037
# ...

# %% [markdown]
# Question 2:
#
# I made my states the name of the city key from the dictionary similar to romania. The action was simply the next city
# that it could go to. When I wanted to determine the value of an option, I grabbed the coordinates for that city from the
# dictionary and I found the difference bewteen the two cities. The result made the action (city) into the current state,
# and I removed that city from a list of cities the algorithm could visit as to void infinite city traveling.
#
# I found that the simulated annealing works slightly better. It isn't simply going to jump between cities based on the cheapest
# possible path, it travels throughout the entire network finding which path is best as its willingness to risk goes down.
# The biggest problem with hill climbing was much the starting node affected the rest, simulated annealing did less of this.

# %%
from csp import backtracking_search
import random
import csp

import itertools




def CourseScheduler():
    courses = "cs108 cs112 cs212 cs214 cs232 cs262 cs344".split()
    variables = courses
    professors = 'VanderLinden Norman, Adams, Bailey'.split()
    times = 'mwf900 mwf1030 tth1130 tth1230'.split()
    classrooms = 'nh253 sb382'.split()
    possibleValues = list(itertools.product(classrooms, professors, times))
    random.shuffle(possibleValues)
    domains = {}
    for course in variables:
        domains[course] = possibleValues
    #print(domains)
    neighbors = {}
    for course in variables:
        courseCopyList = variables[:]
        courseCopyList.remove(course)
        neighborList = courseCopyList
        neighbors[course] = neighborList
    #print(neighbors)

    def constraints(A, a, B, b):
        #print("A " + str(A))
        #print("a " + str(a))
        #print("B " + str(B))
        #print("b " + str(b))
        # Room has space for one class at a time
        one_class_per_room_per_time = True
        # Faculty teaches 1 ting per time slot
        one_faculty_per_time = True
        # Course is taught by only one professor
        one_faculty_per_class = True

        # If the course is the same
        if A == B:
            # Then the same prof should be teaching it
            one_faculty_per_class = a[1] == b[1]
        # if the time is the same, but the course is not the same
        if a[2] == b[2] and A != B:
            # The same prof can't be teaching both classes
            one_faculty_per_time = (a[1] != b[1])
        # if the room is the same, and the time is the same
        if a[0] == b[0] and a[2] == b[2]:
            # then the class should be the same (no two courses in the same room at the same time)
            one_class_per_room_per_time = (A == B)
        return one_faculty_per_class and one_faculty_per_time and one_class_per_room_per_time

    return csp.CSP(variables, domains, neighbors, constraints)

solution = backtracking_search(CourseScheduler())

print(solution)
# Out:
# {'cs108': ('sb382', 'Bailey', 'mwf1030'), 'cs112': ('sb382', 'Bailey', 'mwf900'), 'cs212': ('sb382', 'Norman,', 'tth1230'), 'cs214': ('sb382', 'Bailey', 'tth1130'), 'cs232': ('nh253', 'Adams,', 'mwf1030'), 'cs262': ('nh253', 'VanderLinden', 'tth1130'), 'cs344': ('nh253', 'VanderLinden', 'tth1230')}

# %% [markdown]
# Question 3:
#
# For my problem, I chose to make the courses the variables. I took a list of professors, rooms, times, and I split them.
# Then I created a dictionary of all the possible combinations of these and attached them to each course. Once there was
# this massive amount of possible combinations, I went through and made sure it followed all of the constraints by eliminating
# any of the possibilites that didn't. Once I had done this, it had reduced itself to the schedule I have printed above.
